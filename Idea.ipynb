# %% [markdown]
# # Different at home / at work / energy wasting

# %% [markdown]
# When customer is at home sometime of the day
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# When customer dont stay at home for whole day
# ![image-5.png](attachment:image-5.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# When it is not clear if customer at home while use constant energy OR not at home something is running
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# As we can see on the date 20/1/19, in the time between 9:00 to 18:00 the electro device in the house use little more than the minimal of energy. The fourier analysis for this 2 Situation is almost same -> need to track the average energy to decide

# %% [markdown]
# # Fourier Analysis of back ground device

# %% [markdown]
# Sample per Day: 96 Samples, collecting data every 15 minutes.
#
# Maximal Frequency that we can recognize: 48 (Nyquist Frequency)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## Working days
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## mix days
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Not at home
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Result of using DTW for whole day
# ![image-4.png](attachment:image-4.png)
# ![image-3.png](attachment:image-3.png)
# It gives a wrong result

# %% [markdown]
# ## Try to apply hamming window for the data
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Create a benchmark function to find the best pattern
