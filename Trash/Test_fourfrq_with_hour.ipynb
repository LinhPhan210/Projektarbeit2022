# %%
from scipy.fft import fft, fftfreq, fftshift

import numpy as np
# number of signal points
N = 400
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.exp(50.0 * 1.j * 2.0*np.pi*x) + 0.5*np.exp(-80.0 * 1.j * 2.0*np.pi*x)
yf = fft(y)
xf = fftfreq(N, T)
#xf = fftshift(xf)
#yf = fftshift(yf)
import matplotlib.pyplot as plt
plt.plot(xf, 1.0/N * np.abs(yf))
plt.grid()
plt.show()

# %%
plt.plot(yf)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1390: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import pandas as pd #Using pandas to read csv data

from matplotlib import pyplot as plt #for ploting

import numpy as np

from scipy.fft import fft, fftfreq, fftshift

from scipy import signal

# %%
dataframe = pd.read_csv('./not_GMT.csv', delimiter=',', low_memory=False) #dataframe has type pandas.core.frame.dataframeFrame
totalLine = dataframe.shape[0]
timestampPerDay = 96
offsetCol = 4
N = 8
T = 1.0 / 16.0

def get_data_from_table_1(line, offsetCol, timestampPerDay, dataframe):
    data = dataframe.iloc[line, offsetCol:(offsetCol + timestampPerDay)]
    data = list(data)
    return data

def plot_full_figure(dataList):
    fig = plt.figure()
    ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
    ax.plot(t, dataList)
    ax.set_xlabel('Time')
    #ax.set_title(columnDict[columnNumber])
    #yAx=list(range(0,11))
    #ax.set_yticks([maxValue/10*x for x in yAx])
    plt.ylim(0, 1.05 * 1000)
    ax.set_xticks([0,11,23,35,47,59,71,83,95])
    ax.set_xticklabels(['00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','23:45'])
    plt.show()

t = range(0,96) #for time axes 

window = signal.windows.tukey(8)
#why using tukey window: giu nguyen khoang thoi gian chinh can phan tich

def average(lst):
    return sum(lst) / len(lst)
def plot_figure(data):
    #window_data = np.multiply(data,window)
    #print(average(window_data))
    fig = plt.figure()
    ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
    #ax.set_xlim([xmin, xmax])
    ax.set_ylim([0, 1000])
    plt.plot(data)
    plt.show()
    
def plot_fft(data):
    data = np.multiply(data,window)
    yf = fft(data)
    xf = fftfreq(N, T)
    xf = fftshift(xf)
    yf = fftshift(yf)
    plt.plot(xf, 1.0/N * np.abs(yf))
    plt.grid()
    plt.show()
    
def average_data(data):
    window_data = np.multiply(data,window)
    return average(window_data)

def average_four(data):
    data = np.multiply(data,window)
    dataFT = fft(data,32)
    dataFT = list(map(abs, dataFT))
    return average(dataFT[3:16])

# %%
for line in range(0,totalLine):
    plt.clf()
    date = dataframe.iloc[line,1]
    day = dataframe.iloc[line,2]
    
    data = get_data_from_table_1(line, offsetCol, timestampPerDay, dataframe)
    plot_full_figure(data)
    
    for time in range(8,20):
        time_data = data[time*4:time*4 + 8] #get data in 2 hours
        print(date, "hour" ,time + 1)
        plot_figure(time_data)
        print("average data value: ", average_data(time_data))
        plot_fft(time_data)
        print("average fourier value: ",average_four(time_data))
        
        input()
        #list_data.append(add_data(time_data))
        #list_four.append(add_four(time_data))
# Out:
# Di 01.01.19 hour 9
# average data value:  30.189348278854702
# average fourier value:  43.641546534054406
#
# Di 01.01.19 hour 10
# average data value:  27.946050020015193
# average fourier value:  42.423290477126486
#
# Di 01.01.19 hour 11
# average data value:  32.60758318212535
# average fourier value:  75.59514985891676
#
# Di 01.01.19 hour 12
# average data value:  164.79457910607408
# average fourier value:  499.95749143744865
#
# Di 01.01.19 hour 13
# average data value:  81.78117562375307
# average fourier value:  211.99997738909653
#
# Di 01.01.19 hour 14
# average data value:  97.45008262842546
# average fourier value:  162.78246965428013
#
# Di 01.01.19 hour 15
# average data value:  164.66155243496675
# average fourier value:  213.73854338848827
#
# Di 01.01.19 hour 16
# average data value:  96.85323379587084
# average fourier value:  228.86024879509543
#
# Di 01.01.19 hour 17
# average data value:  92.52382105404747
# average fourier value:  277.2707073045549
#
# Di 01.01.19 hour 18
# average data value:  110.5412378719221
# average fourier value:  341.3197333370811
#
# Di 01.01.19 hour 19
# average data value:  49.70544016678252
# average fourier value:  76.91474499657664
#
# Di 01.01.19 hour 20
# average data value:  57.33613375584045
# average fourier value:  96.53396296654033
# Mi 02.01.19 hour 9
# average data value:  53.67930530354225
# average fourier value:  132.3584353644683
#
# Mi 02.01.19 hour 10
# average data value:  102.09987328886228
# average fourier value:  221.65860719623896
#
# Mi 02.01.19 hour 11
# average data value:  111.85691108072365
# average fourier value:  437.8232688840161
#
# Mi 02.01.19 hour 12
# average data value:  85.29323490327066
# average fourier value:  336.5440707723256
#
# Mi 02.01.19 hour 13
# average data value:  35.72655354236656
# average fourier value:  102.45748353501713
#
# Mi 02.01.19 hour 14
# average data value:  24.855566877920225
# average fourier value:  36.871628773562655
#
# Mi 02.01.19 hour 15
# average data value:  29.32875991327825
# average fourier value:  49.74983773780734
#
# Mi 02.01.19 hour 16
# average data value:  35.77245757838746
# average fourier value:  73.69643036751155
#
# Mi 02.01.19 hour 17
# average data value:  76.64211931288699
# average fourier value:  269.59525986542224
#
# Mi 02.01.19 hour 18
# average data value:  126.44773027351945
# average fourier value:  436.6087830916074
#
# Mi 02.01.19 hour 19
# average data value:  58.27480993329344
# average fourier value:  82.80408326823974
#
# Mi 02.01.19 hour 20
# average data value:  55.22520933956314
# average fourier value:  75.71727706246745
